# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt

# %%
import os 
print(os.getcwd())
# Out:
# C:\Users\anbo

# %%
file_path=r"C:\Users\anbo\Downloads\train (3) (1) (3) (2).csv"
train = pd.read_csv(file_path)

# %%
train.head()
# Out:
#                                      id  App Version Code  App Version Name  \
# 0  b817b0f0-a2f8-4c9d-a5f6-d3fbf8b1d7e9               NaN               NaN
# 1  c7844e8f-56c1-487b-ae3e-df2fdf4c1767              43.0              2.30
# 2  93ff57f7-9e02-4fa9-b779-3db82b8af0a4              52.0              2.12
# 3  df2dcdef-c09a-4f35-afab-e1231d3fec9a              62.0              2.21
# 4  11f8f968-4cec-4424-8427-9709ab05b5be              69.0              2.28
#
#                                          Review Text  Review Title  \
# 0                   Very bad wallet balance not use.           NaN
# 1  Froud app i recharge 199 but not done also sen...           NaN
# 2                       Waste to write comments also  Waste no use
# 3                                           Nice apo           NaN
# 4                                      Good nice app           NaN
#
#    Star Rating
# 0            1
# 1            1
# 2            2
# 3            5
# 4            5

# %%
#Data Analysis
plot_size = plt.rcParams["figure.figsize"] 
print(plot_size[0]) 
print(plot_size[1])

plot_size[0] = 8
plot_size[1] = 6
plt.rcParams["figure.figsize"] = plot_size
# Out:
# 6.0
# 4.0

# %%
train['Star Rating'].value_counts().plot(kind='pie', autopct='%1.0f%%')

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(500, 10), dpi=80)#, facecolor='w', edgecolor='k')

# %%
app_version_sentiment = train.groupby(['App Version Name', 'Star Rating'])['Star Rating'].count().unstack()
app_version_sentiment.plot(kind='bar')

# %%
import seaborn as sns

sns.barplot(x='Star Rating', y='App Version Name' , data=train)

# %%
#Kernel Density Estimation
sns.distplot(train['Star Rating'])
# Out:
# C:\Users\anbo\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='App Version Name',y='Star Rating',data=train)
# Out:
# C:\Users\anbo\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\anbo\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
train = train.dropna()

# %%
sns.pairplot(train)
